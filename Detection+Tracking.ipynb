# %%
from IPython.display import Image

# %%
# !git clone https://github.com/MuhammadMoinFaisal/YOLOv8-DeepSORT-Object-Tracking.git
# Out:
# Cloning into 'YOLOv8-DeepSORT-Object-Tracking'...
# remote: Enumerating objects: 403, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 403 (delta 21), reused 19 (delta 19), pack-reused 370
# Receiving objects: 100% (403/403), 77.99 MiB | 33.50 MiB/s, done.
# Resolving deltas: 100% (206/206), done.

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking

# %%
# !pip install -e '.[dev]'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/YOLOv8-DeepSORT-Object-Tracking
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.5/227.5 kB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 81.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 98.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 15.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.7 MB/s eta 0:00:00
# ...

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="N4b4vgU2fG1r0HiF9zwz")
project = rf.workspace("roboflow-gw7yv").project("vehicles-openimages")
dataset = project.version(1).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics<=8.0.20`, to intall it `pip install ultralytics<=8.0.20`.
# ...
# Extracting Dataset Version Zip to Vehicles-OpenImages-1 in yolov8:: 100%|██████████| 2520/2520 [00:00<00:00, 2714.57it/s]

# %%
# !gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t
# To: /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/deep_sort_pytorch.zip
# 100% 43.1M/43.1M [00:00<00:00, 167MB/s]

# %%
# !unzip 'deep_sort_pytorch.zip'
# Out:
# Archive:  deep_sort_pytorch.zip
#   inflating: deep_sort_pytorch/.gitignore
#    creating: deep_sort_pytorch/configs/
#   inflating: deep_sort_pytorch/configs/deep_sort.yaml
#    creating: deep_sort_pytorch/deep_sort/
#   inflating: deep_sort_pytorch/deep_sort/__init__.py
#    creating: deep_sort_pytorch/deep_sort/__pycache__/
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-310.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-37.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/__init__.cpython-38.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-310.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-37.pyc
#   inflating: deep_sort_pytorch/deep_sort/__pycache__/deep_sort.cpython-38.pyc
#    creating: deep_sort_pytorch/deep_sort/deep/
#  extracting: deep_sort_pytorch/deep_sort/deep/__init__.py
#    creating: deep_sort_pytorch/deep_sort/deep/__pycache__/
# ...

# %%
HOME = '/content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect'

# %%
# %cd {HOME}
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/dataset
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/dataset

# %%
# %cd {HOME}

# !python train.py model=yolov8l.pt data=/content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/dataset/data.yaml epochs=70 imgsz=640
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect
# ...

# %%
# !ls /content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train11
# Out:
# args.yaml					     train_batch2.jpg
# confusion_matrix.png				     train_batch780.jpg
# events.out.tfevents.1682350744.a2ad594cfc57.34844.0  train_batch781.jpg
# F1_curve.png					     train_batch782.jpg
# P_curve.png					     val_batch0_labels.jpg
# PR_curve.png					     val_batch0_pred.jpg
# predictions.json				     val_batch1_labels.jpg
# R_curve.png					     val_batch1_pred.jpg
# results.csv					     val_batch2_labels.jpg
# results.png					     val_batch2_pred.jpg
# train_batch0.jpg				     weights
# train_batch1.jpg

# %%
Image(filename = '/content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train11/confusion_matrix.png')

# %%
Image(filename = r'/content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train11/results.png', width = 600)

# %%
Image(filename = r'/content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train11/val_batch2_pred.jpg', width =600)

# %%
# !pwd
# Out:
# /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %%
# !python val.py model='/content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train11/weights/best.pt' data=/content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/dataset/data.yaml
# Out:
# 2023-04-24 16:04:13.831209: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-24 16:04:15.939858: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.3 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 268 layers, 43617402 parameters, 0 gradients, 164.9 GFLOPs
# val: Scanning /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/dataset/val/labels.cache... 100 images, 1 backgrounds, 0 corrupt: 100% 101/101 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:07<00:00,  1.03s/it]
# ...

# %%
# !python predict.py model='/content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train11/weights/best.pt' source='/content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/vdeodemo.mp4'
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (405/5402) /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/vdeodemo.mp4: 384x640 1 Truck, 20.6ms
# video 1/1 (406/5402) /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/vdeodemo.mp4: 384x640 1 Truck, 19.7ms
# video 1/1 (407/5402) /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/vdeodemo.mp4: 384x640 1 Truck, 19.9ms
# video 1/1 (408/5402) /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/vdeodemo.mp4: 384x640 1 Truck, 1 Van, 20.9ms
# video 1/1 (409/5402) /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/vdeodemo.mp4: 384x640 25.0ms
# video 1/1 (410/5402) /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/vdeodemo.mp4: 384x640 1 Truck, 30.5ms
# video 1/1 (411/5402) /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/vdeodemo.mp4: 384x640 1 Truck, 18.7ms
# ...
